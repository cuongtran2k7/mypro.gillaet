# %% [markdown]
# #### W2A1
# ### Hãy viết chương trình in ra dòng chữ "Hello World!" vào ô dưới đây rồi ấn Nộp bài để kiểm tra xem bạn đã biết cách in một thông báo ra màn hình.

# %%
print("Hello World!")

# %% [markdown]
# #### W2A2
# ### Viết chương trình nhận đầu vào là tên người từ bàn phím và in ra màn hình lời chào tương ứng.

# %%
ten = input()
print("Xin chào", ten)

# %% [markdown]
# #### W2A3
# ### Viết chương trình nhận vào hai số nguyên a, b từ bàn phím. In ra tổng, hiệu, tích, phần nguyên, phần dư và kết quả chia thực của phép chia a cho b (lấy đến 2 chữ số phần thập phân) theo định dạng đúng của output

# %%
a,b=map(int, input().split())

print(a + b)
print(a - b)
print(a * b)
print(a // b)
print(a % b)
print(f"{a / b:.2f}")

# %% [markdown]
# #### W2A4
# ### Viết chương trình python để tính điểm trung bình môn học của một học sinh trong lớp. Có tổng cộng
# ### 6 đầu điểm: a1, b1, c1, a2, b2, a3. Trong đó:
# ### Các điểm a1, b1, c1 được nhân hệ số 1,
# ### Các điểm a2, b2 được nhân hệ số 2,
# ### Điểm a3 được nhân hệ số 3.
# ### Công thức tính điểm trung bình là: TB=((a1+b1+c1)+(a2+b2)×2+a3×3)/10, lấy đến 1 chữ số phần thập phân.

# %%
a1, b1, c1, a2, b2, a3 = map(float, input().split())
tb = (a1 + b1 + c1 + (a2 + b2) * 2 + a3 * 3) / 10
print(f"{tb:.1f}")

# %% [markdown]
# #### W2A5
# ### Trong Python, phép toán mũ (luỹ thừa) được viết bằng **. Ví dụ: để tính 2^3 bạn viết 2**3, và kết quả là 8. Cơ số và số mũ có thể có kiểu float hoặc int. Trong bài này bạn hãy nhập vào hai số a, b (int) cách nhau một dấu cách, tính và in ra kết quả a mũ b.

# %%
a, b = map(int, input().split())
print(a ** b)

# %% [markdown]
# #### W2A6
# ### Hãy nhập vào một kí tự chữ cái thường ‘a’…’z’, in ra mã Unicode của nó sau đó chuyển nó thành kí tự hoa tương ứng, in kí tự hoa này ra màn hình.

# %%
c = input()
print(ord(c))
print(chr(ord(c) - 32))

# %% [markdown]
# #### W2A7
# ### Hãy in ra kết quả của hai biểu thức sau:
# ### A = ((13 ** 2) * 3) + 5 và B = 13**2*3 + 5

# %%
A = ((13 ** 2) * 3) + 5
B = 13**2*3 + 5

print(A)
print(B)

# %% [markdown]
# #### W2A8
# ###  Dựa vào nhiệt độ Celcius được nhập từ bàn phím, hãy chuyển sang độ F theo công thức: F = 9/5*C + 32 và in ra màn hình kết quả. Kết quả làm tròn đến hai chữ số thập phân đằng sau dấu phẩy

# %%
C = float(input())
F = (9/5) * C + 32
print(F)

# %% [markdown]
# #### W2A9
# ### Sơn Tùng mua một chiếc đồng hồ Movado trên trang mua sắm trực tuyến Amazon. Chiếc đồng hồ có giá x USD (x nhập từ bàn phím). Bởi Amazon không vận chuyển trực tiếp về Việt Nam, Đạt phải trả 10 USD cho phí vận chuyển từ một nước trung gian. Khi vận chuyển về Việt Nam, Đạt được thông báo sẽ phải trả thêm 30% thuế xuất nhập cảnh và 10% thuế VAT cho chiếc đồng hồ nói trên. Viết chương trình tính tổng số tiền mà Đạt phải trả để mua được chiếc đồng hồ trên (USD). Kết quả làm tròn đến hai chữ số thập phân

# %%
x = float(input())
tong_chua_thue = x + 10
tong_phai_tra = tong_chua_thue * 1.4
print(f"{tong_phai_tra:.2f}")

# %% [markdown]
# #### W2A10
# ### Viết chương trình nhập vào tên 3 người từ bàn phím.
# ### In ra màn hình tên theo thứ tự đảo ngược.
# ### VD: input ("Bob Alice Helen") thì output: ("Hi Helen, Alice and Bob.")

# %%
ten1, ten2, ten3 = map(input().split())


print(ten3, ten2, ten1)

# %% [markdown]
# #### W2A11
# ### Viết chương trình chuyển từ giờ và phút sang giây
# ### Đầu vào gồm hai giá trị chứa số giờ \h và số phút \m:
# ### Đầu ra: In ra màn hình một dòng duy nhất số giờ và phút được chuyển sang đơn vị giây

# %%
h, m = map(int, input().split())
tong_giay = h * 3600 + m * 60
print(tong_giay)

# %% [markdown]
# #### W2A12
# ### Cho một khối Rubik có độ dài cạnh là n, hãy trả về số lượng miếng dán riêng lẻ cần thiết để bao phủ toàn bộ khối lập phương. Ví dụ, khối rubic có độ dài cạnh là 1 cần 6 miếng dán riêng lẻ.

# %%
n = int(input())
so_mieng_dan = 6 * (n ** 2)
print(so_mieng_dan)

# %% [markdown]
# #### W2A13
# ### Nhập vào từ bàn phím hai số nguyên dương \a và \b, viết chương trình trả về hàng đơn vị của phép tính tích giữa \a và \b.

# %%
a, b = map(int, input().split())
tich = a * b
hang_don_vi = tich % 10
print(hang_don_vi)

# %% [markdown]
# #### W2A14
# ### Viết chương trình hoán đổi giá trị giữa hai số a và b mà không cần khai báo thêm một biến/hàm nào khác.

# %%
a, b = map(int, input().split())
a, b = b, a
print(a, b)

# %% [markdown]
# #### W2A15
# ### Viết chương trình nhận vào một số nguyên dương n và trả về "số sao" thứ n.

# %%
n = int(input())
so_sao = 6 * n * (n - 1) + 1
print(so_sao)

# %% [markdown]
# #### W2A16
# ### Viết vào ô dưới đây chương trình in ra trên màn hình tên các mùa trong năm bằng tiếng Anh
# ### Mỗi mùa in trên một dòng.

# %%
print("Spring\nSummer\nAutumn\nWinter")

# %% [markdown]
# #### W2A17
# ### viết chương trình vẽ ra một tam giác cân bằng các dấu sao trên 3 dòng. Hãy kết hợp việc sử dụng khoảng trắng với các dấu sao để in ra tam giác này.
# ### Ví dụ, đoạn mã để in 2 dòng đầu của tam giác:
# ### print("" * "")
# ### print("" *** "")
# ### Yêu cầu: In ra màn hình tam giác có 3 dòng như sau:
# ### *
# ### ***
# #### ****

# %%
print("  * ")
print(" *** ")
print("*****")

# %% [markdown]
# #### W2A18
# ### Viết chương trình in ra dòng chữ "TDTT" từ các kí hiệu "#"

# %%
print("###  # #    ###   ###")
print(" #  #   #    #     # ")
print(" #  #   #    #     # ")
print(" #  #   #    #     # ")
print(" #  # #      #     # ")

# %% [markdown]
# #### W2A19
# ### Viết chương trình in ra các ngày trong một tuần bằng tiếng Anh. Mỗi ngày in trên một dòng

# %%
print("Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday")

# %% [markdown]
# #### W2A20
# ### Viết chương trình in ra các tháng trong một năm bằng tiếng Anh. Mỗi tháng in trên một dòng, bắt đầu từ "January".

# %%
print("January\nFebruary\nMarch\nApril\nMay\nJune\nJuly\nAugust\nSeptember\nOctober\nNovember\nDecember")

# %% [markdown]
# #### W2A21
# ### Viết chương trình in ra màn hình dòng chữ "Hello, world" 10 lần

# %%
for i in range(10):
    print("Hello, world!")
